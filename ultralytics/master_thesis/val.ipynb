# %% [markdown]
# ## Val KITTI Default

# %%
from ultralytics import YOLO
import torch

# Check for GPU use
print('Use GPU:', torch.cuda.is_available())

if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("GPU cache cleared.\n")

# Results (Car) project work:
# Train: mAP50=89.2%, mAP70=87.9%
# Val: mAP50=89.6%, mAP70=88.5%

# Results (Car) master thesis:
# Train: mAP50=90.6%, mAP70=89.7%
# Val: mAP50=92.0%, mAP70=90.9%

# val PyTorch model FP32
model = YOLO('/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/master_thesis/mt_kitti_bev/default14/weights/yolov11obb_kitti_default.pt', task='obb', verbose=False) 
# val TensorRT FP32 dynamic
#model = YOLO('set_path', task='obb', verbose=False) 
# val TensorRT FP16 dynamic
#model = YOLO('set_path', task='obb', verbose=False)  
# val TensorRT INT8 dynamic
#model = YOLO('set_path', task='obb', verbose=False)

dataset_cfg = '/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/cfg/datasets/kitti_bev.yaml'

metrics = model.val(data=dataset_cfg, imgsz=1024, batch=16, save_json=True, conf=0.001, iou=0.5, max_det=25, half=False,
                    device='1', dnn=False, plots=True, classes=None, rect=False, split='val', project='mt_kitti_bev_val', name='default_val',
                    verbose=True, save_txt=True, save_conf=True, workers=8, augment=False,
                    agnostic_nms=False, single_cls=False, visualize=True, compile=False)

# %% [markdown]
# ## Val KITTI densified

# %%
from ultralytics import YOLO
import torch

# Check for GPU use
print('Use GPU:', torch.cuda.is_available())

if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("GPU cache cleared.\n")

# Results (Car) project work:
# Train: mAP50=89.2%, mAP70=87.9%
# Val: mAP50=89.6%, mAP70=88.5%

# Results (Car) master thesis:
# Train: mAP50=90.0%, mAP70=89.2%
# Val: mAP50=90.8%, mAP70=89.7%

# val PyTorch model FP32
model = YOLO('/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/master_thesis/mt_kitti_bev/densified/weights/yolov11obb_kitti_densified.pt', task='obb', verbose=False) 
# val TensorRT FP32 dynamic
#model = YOLO('set_path', task='obb', verbose=False) 
# val TensorRT FP16 dynamic
#model = YOLO('set_path', task='obb', verbose=False)  
# val TensorRT INT8 dynamic
#model = YOLO('set_path', task='obb', verbose=False)

dataset_cfg = '/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/cfg/datasets/kitti_bev_densified.yaml'

metrics = model.val(data=dataset_cfg, imgsz=1024, batch=16, save_json=True, conf=0.001, iou=0.5, max_det=25, half=False,
                    device='1', dnn=False, plots=True, classes=None, rect=False, split='val', project='mt_kitti_bev_val', name='densified_val',
                    verbose=True, save_txt=True, save_conf=True, workers=8, augment=False,
                    agnostic_nms=False, single_cls=False, visualize=True, compile=False)

# %% [markdown]
# ## Val KITTI interpolated

# %%
from ultralytics import YOLO
import torch

# Check for GPU use
print('Use GPU:', torch.cuda.is_available())

if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("GPU cache cleared.\n")

# Results (Car) project work:
# Train: mAP50=89.2%, mAP70=87.9%
# Val: mAP50=89.6%, mAP70=88.5%

# Results (Car) master thesis:
# Train: mAP50=91.7%, mAP70=90.9%
# Val: mAP50=92.1%, mAP70=91.2%

# val PyTorch model FP32
model = YOLO('/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/master_thesis/mt_kitti_bev/interpolated/weights/yolov11obb_kitti_interp.pt', task='obb', verbose=False) 
# val TensorRT FP32 dynamic
#model = YOLO('set_path', task='obb', verbose=False) 
# val TensorRT FP16 dynamic
#model = YOLO('set_path', task='obb', verbose=False)  
# val TensorRT INT8 dynamic
#model = YOLO('set_path', task='obb', verbose=False)

dataset_cfg = '/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/cfg/datasets/kitti_bev_interp.yaml'

metrics = model.val(data=dataset_cfg, imgsz=1024, batch=16, save_json=True, conf=0.001, iou=0.5, max_det=25, half=False,
                    device='1', dnn=False, plots=True, classes=None, rect=False, split='val', project='mt_kitti_bev_val', name='interpolated_val',
                    verbose=True, save_txt=True, save_conf=True, workers=8, augment=False,
                    agnostic_nms=False, single_cls=False, visualize=True, compile=False)

# %% [markdown]
# ## Val KITTI upsampled

# %%
from ultralytics import YOLO
import torch

# Check for GPU use
print('Use GPU:', torch.cuda.is_available())

if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("GPU cache cleared.\n")

# Results (Car) project work:
# Train: mAP50=89.2%, mAP70=87.9%
# Val: mAP50=89.6%, mAP70=88.5%

# Results (Car) master thesis:
# Train: mAP50=91.4%, mAP70=90.4%
# Val: mAP50=%, mAP70=%

# val PyTorch model FP32
model = YOLO('/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/master_thesis/mt_kitti_bev/upsampled/weights/yolov11obb_kitti_upsampled.pt', task='obb', verbose=False) 
# val TensorRT FP32 dynamic
#model = YOLO('set_path', task='obb', verbose=False) 
# val TensorRT FP16 dynamic
#model = YOLO('set_path', task='obb', verbose=False)  
# val TensorRT INT8 dynamic
#model = YOLO('set_path', task='obb', verbose=False)

dataset_cfg = '/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/cfg/datasets/kitti_bev_upsampled.yaml'

metrics = model.val(data=dataset_cfg, imgsz=1024, batch=16, save_json=True, conf=0.001, iou=0.5, max_det=25, half=False,
                    device='1', dnn=False, plots=True, classes=None, rect=False, split='val', project='mt_kitti_bev_val', name='upsampled_val',
                    verbose=True, save_txt=True, save_conf=True, workers=8, augment=False,
                    agnostic_nms=False, single_cls=False, visualize=True, compile=False)

# %% [markdown]
# ## Val ZOD default

# %%
from ultralytics import YOLO
import torch

# Check for GPU use
print('Use GPU:', torch.cuda.is_available())

if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("GPU cache cleared.\n")

# Results (Car) project work:
# Train: mAP50=89.2%, mAP70=87.9%
# Val: mAP50=89.6%, mAP70=88.5%

# Results (Car) master thesis:
# Train: mAP50=91.4%, mAP70=90.4%
# Val: mAP50=92.8%, mAP70=92.3%

# val PyTorch model FP32
model = YOLO('/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/master_thesis/mt_zod_bev/default/weights/yolov11obb_zod_default.pt', task='obb', verbose=False) 
# val TensorRT FP32 dynamic
#model = YOLO('set_path', task='obb', verbose=False) 
# val TensorRT FP16 dynamic
#model = YOLO('set_path', task='obb', verbose=False)  
# val TensorRT INT8 dynamic
#model = YOLO('set_path', task='obb', verbose=False)

dataset_cfg = '/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/cfg/datasets/zod_bev.yaml'

metrics = model.val(data=dataset_cfg, imgsz=1024, batch=16, save_json=True, conf=0.001, iou=0.5, max_det=25, half=False,
                    device='1', dnn=False, plots=True, classes=None, rect=False, split='val', project='mt_zod_bev_val', name='default_val',
                    verbose=True, save_txt=True, save_conf=True, workers=8, augment=False,
                    agnostic_nms=False, single_cls=False, visualize=True, compile=False)

# %% [markdown]
# ## Test if the DG Methods could close the Domain Gap

# %% [markdown]
# ## DG KITTI default -> ZOD Default

# %%
from ultralytics import YOLO
import torch

# Check for GPU use
print('Use GPU:', torch.cuda.is_available())

if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("GPU cache cleared.\n")

# val PyTorch model FP32
model = YOLO('/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/master_thesis/mt_kitti_bev/default14/weights/yolov11obb_kitti_default.pt', task='obb', verbose=False) 
# val TensorRT FP32 dynamic
#model = YOLO('set_path', task='obb', verbose=False) 
# val TensorRT FP16 dynamic
#model = YOLO('set_path', task='obb', verbose=False)  
# val TensorRT INT8 dynamic
#model = YOLO('set_path', task='obb', verbose=False)

# Validate KITTI trained model on ZOD validation data (64 layers -> 128 layers)
dataset_cfg = '/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/cfg/datasets/zod_bev.yaml'

metrics = model.val(data=dataset_cfg, imgsz=1024, batch=16, save_json=True, conf=0.001, iou=0.5, max_det=25, half=False,
                    device='1', dnn=False, plots=True, classes=None, rect=False, split='val', project='mt_dg_kitti_zod', name='default_val',
                    verbose=True, save_txt=True, save_conf=True, workers=8, augment=False,
                    agnostic_nms=False, single_cls=False, visualize=True, compile=False)

# %% [markdown]
# ## DG KITTI densified -> ZOD Default

# %%
from ultralytics import YOLO
import torch

# Check for GPU use
print('Use GPU:', torch.cuda.is_available())

if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("GPU cache cleared.\n")

# val PyTorch model FP32
model = YOLO('/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/master_thesis/mt_kitti_bev/densified/weights/yolov11obb_kitti_densified.pt', task='obb', verbose=False) 
# val TensorRT FP32 dynamic
#model = YOLO('set_path', task='obb', verbose=False) 
# val TensorRT FP16 dynamic
#model = YOLO('set_path', task='obb', verbose=False)  
# val TensorRT INT8 dynamic
#model = YOLO('set_path', task='obb', verbose=False)

# Validate KITTI trained model on ZOD validation data (64 layers -> 128 layers)
dataset_cfg = '/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/cfg/datasets/zod_bev.yaml'

metrics = model.val(data=dataset_cfg, imgsz=1024, batch=16, save_json=True, conf=0.001, iou=0.5, max_det=25, half=False,
                    device='1', dnn=False, plots=True, classes=None, rect=False, split='val', project='mt_dg_kitti_zod', name='densified_val',
                    verbose=True, save_txt=True, save_conf=True, workers=8, augment=False,
                    agnostic_nms=False, single_cls=False, visualize=True, compile=False)

# %% [markdown]
# ## DG KITTI interpolated -> ZOD Default

# %%
from ultralytics import YOLO
import torch

# Check for GPU use
print('Use GPU:', torch.cuda.is_available())

if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("GPU cache cleared.\n")

# val PyTorch model FP32
model = YOLO('/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/master_thesis/mt_kitti_bev/interpolated/weights/yolov11obb_kitti_interp.pt', task='obb', verbose=False) 
# val TensorRT FP32 dynamic
#model = YOLO('set_path', task='obb', verbose=False) 
# val TensorRT FP16 dynamic
#model = YOLO('set_path', task='obb', verbose=False)  
# val TensorRT INT8 dynamic
#model = YOLO('set_path', task='obb', verbose=False)

# Validate KITTI trained model on ZOD validation data (64 layers -> 128 layers)
dataset_cfg = '/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/cfg/datasets/zod_bev.yaml'

metrics = model.val(data=dataset_cfg, imgsz=1024, batch=16, save_json=True, conf=0.001, iou=0.5, max_det=25, half=False,
                    device='1', dnn=False, plots=True, classes=None, rect=False, split='val', project='mt_dg_kitti_zod', name='interpolated_val',
                    verbose=True, save_txt=True, save_conf=True, workers=8, augment=False,
                    agnostic_nms=False, single_cls=False, visualize=True, compile=False)

# %% [markdown]
# ## DG KITTI upsampled -> ZOD Default

# %%
from ultralytics import YOLO
import torch

# Check for GPU use
print('Use GPU:', torch.cuda.is_available())

if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("GPU cache cleared.\n")

# val PyTorch model FP32
model = YOLO('/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/master_thesis/mt_kitti_bev/upsampled/weights/yolov11obb_kitti_upsampled.pt', task='obb', verbose=False) 
# val TensorRT FP32 dynamic
#model = YOLO('set_path', task='obb', verbose=False) 
# val TensorRT FP16 dynamic
#model = YOLO('set_path', task='obb', verbose=False)  
# val TensorRT INT8 dynamic
#model = YOLO('set_path', task='obb', verbose=False)

# Validate KITTI trained model on ZOD validation data (64 layers -> 128 layers)
dataset_cfg = '/home/heizung1/ultralytics_yolov8-obb_ob_kitti/ultralytics/cfg/datasets/zod_bev.yaml'

metrics = model.val(data=dataset_cfg, imgsz=1024, batch=16, save_json=True, conf=0.001, iou=0.5, max_det=25, half=False,
                    device='1', dnn=False, plots=True, classes=None, rect=False, split='val', project='mt_dg_kitti_zod', name='upsampled_val',
                    verbose=True, save_txt=True, save_conf=True, workers=8, augment=False,
                    agnostic_nms=False, single_cls=False, visualize=True, compile=False)
